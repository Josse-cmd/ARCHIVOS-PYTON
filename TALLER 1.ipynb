# %%
#TALLER 1-Ingreso de datos
numeroID_per = input("Digite su numero de identificacion: ")
print(numeroID_per)
nombre_per = input("Digite su nombre: ")
print(nombre_per)
apellido_per = input("Digite su apellido: ")
print(apellido_per)
direccion = input("Digite su direccion: ")
print(direccion)
telefono = input("Digite su numero de contacto: ")
print(telefono)
edad = input("Digite su edad: ")
print(edad)
estado_civil = input("Digite su estado civil: ")
print(estado_civil)
hijos = input("Digite numero de hijos: ")
print(hijos)
estatura_cent = input("Digite su estatura en centimetros: ")
print(estatura_cent)
fecha_contratacion = input("Digite la fecha de contratacion Dia/Mes/Año: ")
print(fecha_contratacion)
sueldo = input("Digite su sueldo basico: ")
print(sueldo)
dias_laborados = input("Digite los dias laborados: ")
print(dias_laborados)3
# Out:
# Digite su numero de identificacion: 1075669133
# 1075669133
# Digite su nombre: JOSE
# JOSE
# Digite su apellido: CHAVES
# CHAVES
# Digite su direccion: CALLE 26
# CALLE 26
# Digite su numero de contacto: 3012183357
# 3012183357
# Digite su edad: 30
# 30
# Digite su estado civil: SOLTERO
# SOLTERO
# Digite numero de hijos: 0
# 0
# Digite su estatura en centimetros: 171
# 171
# Digite la fecha de contratacion Dia/Mes/Año: 10/10/2022
# 10/10/2022
# Digite su sueldo basico: 2000000
# 2000000
# Digite los dias laborados: 30
# 30
